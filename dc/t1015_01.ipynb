# %%
import readline
from PyPDF2 import PdfReader

# %%
reader = PdfReader("111.pdf")

# %%
from matplotlib.textpath import text_to_path

text = ""
for page in reader.pages:
    text += page.extract_text() + "\n"

# %%
print(text)
# Out:
# 明新科技大學 111學年度第 1學期行事曆
#                                                                             111 年4 月12日行政會議 提案
# 111年8月22日學務處公告
# 中 華 民 國 111 年 8 月 1 日 至 112 年 1 月 31 日
# 月份 週次 日 一 二 三 四 五 六 重   要   行   事
# 111
# 年
# 8
# 月 暑假  1 2 3 4 5 6  8/1 111學年度第 1學期開始 、 8/5共同休假
# 暑假 7 8 9 10 11 12 13  8/12共同休假
# 暑假 14 15 16 17 18 19 20  8/16四技聯合登記分發新生歡迎會 、 8/19共同休假
# 暑假 21 22 23 24 25 26 27  8/26共同休假
# 暑假 28 29 30 31     8/28 新生入住學生宿舍日 、 8/29-9/8 雙主修與輔系申請
# 9
# 月 預備     1 2 3  9/1全校教師 教學研習會、全校教師輔導知能研習
#  9/1 進修學生 新生定向輔導
#  9/1-9/13 開放延修生 (大學部)選課
#  9/2-9/13 開放網路選課
#  9/2 新生定向輔導暨新生健康檢查 、進修學生 新生體檢
# 9/3-9/4 學生宿舍入住日
# 一 4 5 6 7 8 9 10  9/5 開學日、 9/5 本日(含)以前休、退學者免繳費
#  9/8 進修部辦理人工選課
#  9/10 中秋節放假一日 (9/9補假)
# 二 11 12 13 14 15 16 17  9/14-9/16 日間部隨進修部網路選課開放 、進修部隨日間部開放網路選課
#  9/14 新生社團博覽會
# 三 18 19 20 21 22 23 24  9/21 進修部導師會議
# 四 25 26 27 28 29 30   9/26-10/12 校內轉系申請  、 9/28 師生產學日
# 10
# 月 四       1
# 五 2 3 4 5 6 7 8  10/5  教務會議
# ...

# %%
text1 = text.find('開放網路選課')
print(text1)
# Out:
# 551

# %%
text2 = text1
text1 += 6
while (True):
    if(str('/')) == (text[text2]):
        text2-=1
        break
    else:

        text2-=1;
    
print(text2)
while (True):
    if(str('/')) == (text[text2]):
        text2-=1
        break
    else:

        text2-=1;
    
print(text2)
# Out:
# 546
# 542

# %%
print(text[text2:text1])
# Out:
# 9/2-9/13 開放網路選課
