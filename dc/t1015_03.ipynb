# %%
import readline
from PyPDF2 import PdfReader

# %%
reader = PdfReader("110-2.pdf")

# %%
from matplotlib.textpath import text_to_path

text = ""
for page in reader.pages:
    text += page.extract_text() + "\n"

# %%
print(text)
# Out:
# 明新科技大學 110 學年度第 2 學期各單位行事摘要
# 中 華 民 國 111 年 2 月 1 日 至 111 年 7 月 31 日
# 月份         星 期
# 週 次 日 一 二 三 四 五 六 重   要   行   事
# 111
# 年
# 2
# 月    1 2 3 4 5 2/1 110 學年度第 2 學期開始
# 2/1 補辦理 110 學年度第 2 學期汽、機車入校申請
# 2/14-2/25 雙主修與輔系申請
# 2/14 教學大綱輸入截止日
# 2/14-2/18 校園安全反針孔檢測
# 2/17 全校教師教學研討會
# 2/17 全校導師(教師)輔導知能研習活動
# 2/17 上午 10:00-3/1下午 5:00 止開放網路選課 (2/17限大學部延修生)
# 2/18 校教師評審委員會(下午 1:00)
# 2/19-2/20 宿舍進住
# 2/21 開學日
# 2/21 本日(含)以前休、退學者免繳費
# 2/21 就學貸款、學雜費減免紙本收件截止
# 2/21 勞作教育編組實施(中午 12 點)
# 2/21-2/25 友善校園週
# 2/21-3/11 校園安全自主檢核
# 2/28 和平紀念日放假一日
# ◎進修部：2/14 教學大綱輸入截止日
# ◎進修部：2/14-25 雙主修與輔系申請
# ◎進修部：2/17-3/1 開放延修生(大學部)選課
# ◎進修部：2/18-3/1 開放網路選課(2/18 18:00至 3/1 23:59)
# ◎進修部：2/21 開學，18:30 正式上課
# ◎進修部：2/21-3/4 學雜費減免受理「補申請」
# ◎進修部：2/21-3/4 「品學兼優獎學金、熱心服務獎學金、玄通畢業成績特
# 優獎」受理申請
# ◎進修部：2/24 辦理人工選課(18:00至 21:00)
# ◎進修部：2/25 就學貸款截止收件日
#   6 7 8 9 10 11 12
# 預備週 13 14 15 16 17 18 19
# 第一週 20 21 22 23 24 25 26
# 第二週 27 28
# 3
# 月 第二週   1 2 3 4 5 3/2 期初社團負責人會議/社團指導老師會議(中午 12:00 至下午 1:00)
# 3/2-3/4 日間部隨進修部開放網路選課
# ...

# %%
text1 = text.find('開放網路選課')
print(text1)
# Out:
# 320

# %%
text2 = text1
text1 += 6
while (True):
    if(str('/')) == (text[text2]):
        text2-=1
        break
    else:

        text2-=1;
    
print(text2)
while (True):
    if(str('/')) == (text[text2]):
        text2-=1
        break
    else:

        text2-=1;
    
print(text2)
# Out:
# 308
# 294

# %%
print(text[text2:text1])
# Out:
# 2/17 上午 10:00-3/1下午 5:00 止開放網路選課
